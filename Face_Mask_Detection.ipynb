# %% [markdown]
# <a href="https://colab.research.google.com/github/vp1099/Face-Mask-Detection-Keras-ML/blob/main/Face_Mask_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BASE : GOOGLE DRIVE MOUNT STEP**

# %%
#To mount gdrive and get to our base directory of the project
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/Facial-Mask-Detection-development
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Facial-Mask-Detection-development

# %% [markdown]
# **Block-1 : Import Necessary Modules**

# %%
# We need to import the following libraries for our demo code to function correctly
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# **Block-2 : Import all Module .py files**

# %%
#To load all the different modules required for complete functionality
#Architecture : Contains the complete architecture of model and all the helping functions to perform the task
#Data_Loading : Contains the functions to load and pre-process the data
#Test : Contains the functions to test the model and present the evaluation report as well as function for acatual prediction
#Train : Contains the functions to train the model, save it and produce training history

from Files import Architecture
from Files import Data_Loading
from Files import Test
from Files import Train

# %% [markdown]
# **Block-3 : Dataset Path and Hyper Parameters**

# %%
# path for input images/data
images_path = 'dataset'

# hyper parameters setting
#batch_size : General value is set as normally taken
#lr = learning rate : After testing and getting best results
#epochs : The optimal amount of epochs to attain best results

hyper_params = {"lr": 1e-4,"batch_size": 32,"epochs": 20}

# %% [markdown]
# **Block-4 : Load Dataset**

# %%
# Load images using the function present in Data_Loading module
trainX, testX, trainY, testY =Data_Loading.load_images_and_labels(images_path)
# Out:
# [INFO] Loading Images......
# [INFO] Loaded

# %% [markdown]
# **Block-5 : Sample from Dataset**

# %%
# view sample loaded image
plt.axis('off')
plt.imshow(trainX[1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Block-6 : Load Model(if applicable)**

# %%
#If you already have a trained model present and want to use it directly then run this cell to load the saved model
model = tf.keras.models.load_model('classifier_model.h5')

# %% [markdown]
# **Block-7 : Build Model(if not loaded already)**

# %%
#build the model from Architecture file if not loaded already
model = Architecture.fine_tune_architecture()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# **Block-8 : Train Model**

# %%
#train model and get model as well as training history using the function training from the Train module
model, history = Train.training(model,trainX, testX, trainY, testY, hyper_params)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 35/35 [==============================] - 47s 1s/step - loss: 0.1816 - accuracy: 0.9282 - val_loss: 0.0162 - val_accuracy: 0.9964
# Epoch 2/20
# 35/35 [==============================] - 43s 1s/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.0331 - val_accuracy: 0.9855
# Epoch 3/20
# 35/35 [==============================] - 43s 1s/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.0145 - val_accuracy: 0.9964
# Epoch 4/20
# 35/35 [==============================] - 44s 1s/step - loss: 0.0162 - accuracy: 0.9973 - val_loss: 0.0224 - val_accuracy: 0.9891
# Epoch 5/20
# 35/35 [==============================] - 49s 1s/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.0126 - val_accuracy: 0.9964
# Epoch 6/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0127 - accuracy: 0.9973 - val_loss: 0.0166 - val_accuracy: 0.9928
# Epoch 7/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.0170 - val_accuracy: 0.9855
# Epoch 8/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.0220 - val_accuracy: 0.9855
# Epoch 9/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 0.0330 - val_accuracy: 0.9855
# Epoch 10/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.0141 - val_accuracy: 0.9928
# Epoch 11/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0083 - accuracy: 0.9964 - val_loss: 0.0306 - val_accuracy: 0.9819
# Epoch 12/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0082 - accuracy: 0.9964 - val_loss: 0.0154 - val_accuracy: 0.9855
# Epoch 13/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0337 - val_accuracy: 0.9819
# Epoch 14/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 15/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0101 - val_accuracy: 0.9964
# Epoch 16/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0070 - val_accuracy: 0.9964
# Epoch 17/20
# 35/35 [==============================] - 44s 1s/step - loss: 0.0096 - accuracy: 0.9964 - val_loss: 0.0122 - val_accuracy: 0.9928
# Epoch 18/20
# 35/35 [==============================] - 44s 1s/step - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.0300 - val_accuracy: 0.9855
# Epoch 19/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0332 - val_accuracy: 0.9855
# Epoch 20/20
# 35/35 [==============================] - 45s 1s/step - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.0172 - val_accuracy: 0.9964
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# [INFO] Model Saved to Disk !

# %% [markdown]
# **Block-9 : Model Training History**

# %%
#Plot the Accuracy history as well as Loss history of the Training and Validation Data
Train.plot_accuracy_history(history)
Train.plot_loss_history(history)

# %% [markdown]
# **Block-10 : Evaluate Model**

# %%
#Evaluate the model on Test data and generate Precision , Recall , AUC and ROC Curve
Test.evalute_report(model,testX,testY,hyper_params)
# Out:
# [INFO] evaluating network...
#
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       138
#            1       1.00      0.99      1.00       138
#
#     accuracy                           1.00       276
#    macro avg       1.00      1.00      1.00       276
# weighted avg       1.00      1.00      1.00       276
#
#
# AUC: 1.00

# %% [markdown]
# **Block-11 : Sample Detections**

# %%
#To check the result of testing our model on some sample images
plt.figure(figsize=(36,16))
for i in range(6):
    plt.subplot(2,3,i+1)
    Test.show_img(str(i+1)+".jpg")
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8f4a68a3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8f467108c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# **Block-12 : Difficult Sample Detection**

# %%
#To check our model's result on a difficult sample image
Test.show_img("10.webp")

# %% [markdown]
# **Block-13 : Google Colab Webcam Integration**

# %%
#When running the file on Google Colab run this cell to use webcam to take an image
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='examples/photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename.split("/")[1]

image_file = take_photo()

# %% [markdown]
# **Block-14 : Google Colab Webcam Image Prediction**

# %%
#Now check the result produced by model on the Image taken by running the cell above this cell
Test.show_img(image_file)

# %% [markdown]
# **Block-15 : Webcam Live Results Demo**

# %%
#When running on local machine run this cell for live webcam face mask detection using our model
Architecture.mask_detection_video()
